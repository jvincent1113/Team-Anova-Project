# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3

# %%
conn = sqlite3.Connection("data/data2.sqlite")

# %%
salary_data = pd.read_csv('salary_data_states.csv')
salary_data
# Out:
#                CASE_NUMBER          CASE_STATUS CASE_RECEIVED_DATE  \
# 0       I-200-14073-248840               denied          3/14/2014
# 1            A-15061-55212               denied          3/19/2015
# 2       I-200-13256-001092               denied          9/13/2013
# 3       I-200-14087-353657               denied          3/28/2014
# 4       I-203-14259-128844               denied          9/16/2014
# ...                    ...                  ...                ...
# 167273  I-200-12241-209885  certified-withdrawn          8/28/2012
# 167274  I-200-11305-143547               denied          11/1/2011
# 167275  I-200-11313-833007            certified          11/9/2011
# 167276  I-200-11312-798611               denied          11/8/2011
# 167277  I-200-11297-523711               denied         10/24/2011
#
#        DECISION_DATE                                      EMPLOYER_NAME  \
# 0          3/21/2014                ADVANCED TECHNOLOGY GROUP USA, INC.
# ...

# %% [markdown]
# # I. Do specific sub-types of data-related jobs have higher or lower salaries than others? (Alyssa)

# %%
hour_wage = salary_data[salary_data['PREVAILING_WAGE_SUBMITTED_UNIT'] == 'year']
hour_wage = salary_data.groupby('JOB_TITLE_SUBGROUP')['PREVAILING_WAGE_SUBMITTED'].mean()
                                
print(hour_wage)
# Out:
# JOB_TITLE_SUBGROUP
# assistant professor      55350.886796
# attorney                 91326.411022
# business analyst         59356.259678
# data analyst             59861.359354
# data scientist           89799.037408
# management consultant    47947.593416
# software engineer        82212.129471
# teacher                  37829.948856
# Name: PREVAILING_WAGE_SUBMITTED, dtype: float64

# %%
employer_wage = salary_data[salary_data['PREVAILING_WAGE_SUBMITTED_UNIT'] == 'year']
employer_wage = salary_data.groupby('EMPLOYER_NAME')['PREVAILING_WAGE_SUBMITTED'].median()

employer_wage.sort_values(ascending=False).head(10)
# Out:
# EMPLOYER_NAME
# SECURE ENDPOINTS, INC.                890000.0
# DTC GLOBAL SERVICES LLC               870006.0
# ACTIVE ENTERPRISE SOLUTIONS LLC       300300.0
# HERITAGE PREPARATORY ACADEMY, INC.    227535.0
# SCHOOL BOARD MIAMI-DADE COUNTY        222750.0
# HANSON BRIDGETT LLP                   210912.0
# FENWICK &AMP; WEST LLP                209414.0
# KAYE SCHOLER LLP                      207293.0
# LOWENSTEIN SANDLER LLP                207293.0
# BRACEWELL & GIULIANI LLP              207293.0
# Name: PREVAILING_WAGE_SUBMITTED, dtype: float64

# %%
employer_wage.describe()
# Out:
# count     23773.000000
# mean      64607.462201
# std       31708.790073
# min           7.250000
# 25%       47486.000000
# 50%       65229.000000
# 75%       84500.000000
# max      890000.000000
# Name: PREVAILING_WAGE_SUBMITTED, dtype: float64

# %%
active_enter = salary_data[salary_data['EMPLOYER_NAME'] == 'ACTIVE ENTERPRISE SOLUTIONS LLC']
active_enter
# Out:
#                CASE_NUMBER CASE_STATUS CASE_RECEIVED_DATE DECISION_DATE  \
# 43      I-200-13072-274889      denied          3/13/2013     3/18/2013
# 130997  I-200-13077-890611   certified          3/18/2013     3/22/2013
#
#                           EMPLOYER_NAME  PREVAILING_WAGE_SUBMITTED  \
# 43      ACTIVE ENTERPRISE SOLUTIONS LLC                   546000.0
# 130997  ACTIVE ENTERPRISE SOLUTIONS LLC                    54600.0
#
#        PREVAILING_WAGE_SUBMITTED_UNIT  PAID_WAGE_SUBMITTED  \
# 43                               year              54600.0
# 130997                           year              54650.0
#
#        PAID_WAGE_SUBMITTED_UNIT         JOB_TITLE  ...  \
# 43                         year  BUSINESS ANALYST  ...
# 130997                     year  BUSINESS ANALYST  ...
#
#        PREVAILING_WAGE_SOC_TITLE WORK_STATE WORK_STATE_ABBREVIATION  \
# 43           Management Analysts      Texas                      TX
# ...

# %%
dtc_enter = salary_data[salary_data['EMPLOYER_NAME'] == 'DTC GLOBAL SERVICES LLC']
dtc_enter
# Out:
#            CASE_NUMBER CASE_STATUS CASE_RECEIVED_DATE DECISION_DATE  \
# 22  I-200-13073-435787   withdrawn          3/14/2013     3/15/2013
#
#               EMPLOYER_NAME  PREVAILING_WAGE_SUBMITTED  \
# 22  DTC GLOBAL SERVICES LLC                   870006.0
#
#    PREVAILING_WAGE_SUBMITTED_UNIT  PAID_WAGE_SUBMITTED  \
# 22                           year             135000.0
#
#    PAID_WAGE_SUBMITTED_UNIT          JOB_TITLE  ...  \
# 22                     year  SOFTWARE ENGINEER  ...
#
#             PREVAILING_WAGE_SOC_TITLE            WORK_STATE  \
# 22  Software Developers, Applications  District of Columbia
#
#    WORK_STATE_ABBREVIATION WORK_POSTAL_CODE  FULL_TIME_POSITION_Y_N  \
# 22                      DC              NaN                       y
#
#    VISA_CLASS PREVAILING_WAGE_PER_YEAR PAID_WAGE_PER_YEAR JOB_TITLE_SUBGROUP  \
# 22       H-1B                      NaN           135000.0  software engineer
#
#    order
# 22    23
#
# [1 rows x 27 columns]

# %%
secure_enter = salary_data[salary_data['EMPLOYER_NAME'] == 'SECURE ENDPOINTS, INC.']
secure_enter
# Out:
#            CASE_NUMBER CASE_STATUS CASE_RECEIVED_DATE DECISION_DATE  \
# 19  I-200-13274-808058   withdrawn          10/1/2013     10/1/2013
#
#              EMPLOYER_NAME  PREVAILING_WAGE_SUBMITTED  \
# 19  SECURE ENDPOINTS, INC.                   890000.0
#
#    PREVAILING_WAGE_SUBMITTED_UNIT  PAID_WAGE_SUBMITTED  \
# 19                           year             100001.0
#
#    PAID_WAGE_SUBMITTED_UNIT          JOB_TITLE  ...  \
# 19                     year  SOFTWARE ENGINEER  ...
#
#             PREVAILING_WAGE_SOC_TITLE WORK_STATE WORK_STATE_ABBREVIATION  \
# 19  Software Developers, Applications   New York                      NY
#
#    WORK_POSTAL_CODE  FULL_TIME_POSITION_Y_N VISA_CLASS  \
# 19              NaN                       y       H-1B
#
#    PREVAILING_WAGE_PER_YEAR PAID_WAGE_PER_YEAR JOB_TITLE_SUBGROUP order
# 19                      NaN           100001.0  software engineer    20
#
# [1 rows x 27 columns]
