# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
salary_data = pd.read_csv('salary_data_states-csv.csv')
salary_data
# Out:
#                CASE_NUMBER          CASE_STATUS CASE_RECEIVED_DATE  \
# 0       I-200-14073-248840               denied          3/14/2014
# 1            A-15061-55212               denied          3/19/2015
# 2       I-200-13256-001092               denied          9/13/2013
# 3       I-200-14087-353657               denied          3/28/2014
# 4       I-203-14259-128844               denied          9/16/2014
# ...                    ...                  ...                ...
# 167273  I-200-12241-209885  certified-withdrawn          8/28/2012
# 167274  I-200-11305-143547               denied          11/1/2011
# 167275  I-200-11313-833007            certified          11/9/2011
# 167276  I-200-11312-798611               denied          11/8/2011
# 167277  I-200-11297-523711               denied         10/24/2011
#
#        DECISION_DATE                                      EMPLOYER_NAME  \
# 0          3/21/2014                ADVANCED TECHNOLOGY GROUP USA, INC.
# ...

# %%
# Column Headings

salary_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167278 entries, 0 to 167277
# Data columns (total 27 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   CASE_NUMBER                     167278 non-null  object
#  1   CASE_STATUS                     167278 non-null  object
#  2   CASE_RECEIVED_DATE              167278 non-null  object
#  3   DECISION_DATE                   167278 non-null  object
#  4   EMPLOYER_NAME                   167278 non-null  object
#  5   PREVAILING_WAGE_SUBMITTED       167278 non-null  float64
#  6   PREVAILING_WAGE_SUBMITTED_UNIT  167278 non-null  object
#  7   PAID_WAGE_SUBMITTED             167278 non-null  float64
#  8   PAID_WAGE_SUBMITTED_UNIT        167278 non-null  object
#  9   JOB_TITLE                       167278 non-null  object
#  10  WORK_CITY                       167275 non-null  object
#  11  EDUCATION_LEVEL_REQUIRED        11093 non-null   object
# ...

# %%
# Provides Overall Breakdown of Statistical Measures by Column

salary_data.describe()
# Out:
#        PREVAILING_WAGE_SUBMITTED  PAID_WAGE_SUBMITTED  \
# count               1.672780e+05         1.672780e+05
# mean                7.115752e+04         8.164186e+04
# std                 3.874624e+04         4.147703e+04
# min                 5.050000e+00         5.050000e+00
# 25%                 5.447500e+04         6.100000e+04
# 50%                 6.970100e+04         7.700000e+04
# 75%                 8.993700e+04         1.000000e+05
# max                 6.217100e+06         2.500000e+06
#
#        EXPERIENCE_REQUIRED_NUM_MONTHS  PREVAILING_WAGE_PER_YEAR  \
# count                     4965.000000             167210.000000
# mean                        34.692044              74274.868236
# std                         22.317783              25356.245893
# min                          0.000000              10504.000000
# 25%                         12.000000              56880.000000
# 50%                         24.000000              70928.000000
# ...

# %%
salary_data.head()
# Out:
#           CASE_NUMBER CASE_STATUS CASE_RECEIVED_DATE DECISION_DATE  \
# 0  I-200-14073-248840      denied          3/14/2014     3/21/2014
# 1       A-15061-55212      denied          3/19/2015     3/19/2015
# 2  I-200-13256-001092      denied          9/13/2013     9/23/2013
# 3  I-200-14087-353657      denied          3/28/2014      4/7/2014
# 4  I-203-14259-128844      denied          9/16/2014     9/23/2014
#
#                                        EMPLOYER_NAME  \
# 0                ADVANCED TECHNOLOGY GROUP USA, INC.
# 1                     SAN FRANCISCO STATE UNIVERSITY
# 2                                    CAROUSEL SCHOOL
# 3  HARLINGEN CONSOLIDATED INDEPENDENT SCHOOL DIST...
# 4                        SIGNAL SCIENCES CORPORATION
#
#    PREVAILING_WAGE_SUBMITTED PREVAILING_WAGE_SUBMITTED_UNIT  \
# 0                  6217100.0                           year
# 1                  5067600.0                           year
# ...

# %%
salary_data.tail()
# Out:
#                CASE_NUMBER          CASE_STATUS CASE_RECEIVED_DATE  \
# 167273  I-200-12241-209885  certified-withdrawn          8/28/2012
# 167274  I-200-11305-143547               denied          11/1/2011
# 167275  I-200-11313-833007            certified          11/9/2011
# 167276  I-200-11312-798611               denied          11/8/2011
# 167277  I-200-11297-523711               denied         10/24/2011
#
#        DECISION_DATE                             EMPLOYER_NAME  \
# 167273      6/6/2013  CHINESE BIBLE CHURCH INTERNATIONAL, INC.
# 167274     11/3/2011  CHINESE BIBLE CHURCH INTERNATIONAL, INC.
# 167275    11/16/2011  CHINESE BIBLE CHURCH INTERNATIONAL, INC.
# 167276    11/15/2011  CHINESE BIBLE CHURCH INTERNATIONAL, INC.
# 167277    10/26/2011  CHINESE BIBLE CHURCH INTERNATIONAL, INC.
#
#         PREVAILING_WAGE_SUBMITTED PREVAILING_WAGE_SUBMITTED_UNIT  \
# 167273                       5.05                           hour
# ...

# %%
# Highest Earners

salary_data['PAID_WAGE_PER_YEAR'].nlargest()
# Out:
# 232    2500000.0
# 160    2400000.0
# 266    2400000.0
# 267    2400000.0
# 268    2400000.0
# Name: PAID_WAGE_PER_YEAR, dtype: float64

# %%
# Lowest Earners

salary_data['PAID_WAGE_PER_YEAR'].nsmallest()
# Out:
# 156647    10500.0
# 167267    10504.0
# 167277    10504.0
# 167276    10608.0
# 167274    10920.0
# Name: PAID_WAGE_PER_YEAR, dtype: float64

# %%
# Full-Time Employees Amongst Results

salary_data['FULL_TIME_POSITION_Y_N'].value_counts()
# Out:
# y    152594
# n      3591
# Name: FULL_TIME_POSITION_Y_N, dtype: int64

# %%
# Count of Jobs Listed as College Major Req. 

salary_data['COLLEGE_MAJOR_REQUIRED'].value_counts()
# Out:
# computer science                                                             1521
# computer science, computer engg., electrical engg., or related field          502
# any field                                                                     283
# electrical engineering, computer engineering, computer science or related     195
# education                                                                     158
#                                                                              ...
# physics or mathematics                                                          1
# management science                                                              1
# computer science,mathematics, soft. engineering                                 1
# computer science,mathematics,soft. engineering                                  1
# mass communications                                                             1
# Name: COLLEGE_MAJOR_REQUIRED, Length: 3261, dtype: int64

# %%
# Count of Jobs Requiring Diff. Levels of Education

salary_data['EDUCATION_LEVEL_REQUIRED'].value_counts()
# Out:
# Master's       5550
# Bachelor's     3938
# Doctorate      1181
# Other           366
# None             30
# Associate's      21
# High School       7
# Name: EDUCATION_LEVEL_REQUIRED, dtype: int64

# %%
# Highest Density Cities for Job Data Sample

salary_data['WORK_CITY'].value_counts()
# Out:
# NEW YORK         6714
# MOUNTAIN VIEW    6712
# SAN FRANCISCO    6458
# SAN DIEGO        2983
# SAN JOSE         2925
#                  ...
# TUPELO              1
# Northfield          1
# Marianna            1
# San Anotnonio       1
# DEL RIO             1
# Name: WORK_CITY, Length: 4888, dtype: int64

# %%
# Count Within States Where Job Data Was Captured

salary_data['WORK_STATE'].value_counts()
# Out:
# California                  46782
# Texas                       15498
# New York                    11373
# New Jersey                  10198
# Illinois                     7411
# Massachusetts                6848
# Virginia                     6031
# Georgia                      5615
# Pennsylvania                 4725
# Washington                   4610
# Florida                      4064
# Michigan                     3844
# North Carolina               3578
# Maryland                     3275
# Ohio                         3192
# Missouri                     2773
# Arizona                      2570
# Minnesota                    2116
# Connecticut                  2023
# Indiana                      1617
# Colorado                     1614
# Oregon                       1535
# Wisconsin                    1433
# District of Columbia         1370
# Tennessee                    1087
# Iowa                         1012
# Louisiana                     883
# ...

# %%
# Highest Employees Country of Citizenship Count

salary_data['COUNTRY_OF_CITIZENSHIP'].value_counts()
# Out:
# INDIA                    6587
# CHINA                    1101
# CANADA                    425
# PHILIPPINES               300
# SOUTH KOREA               269
#                          ...
# SERBIA AND MONTENEGRO       1
# ANTIGUA AND BARBUDA         1
# ICELAND                     1
# CYPRUS                      1
# PARAGUAY                    1
# Name: COUNTRY_OF_CITIZENSHIP, Length: 134, dtype: int64

# %%
# Types of Visas Count

salary_data['VISA_CLASS'].value_counts()
# Out:
# H-1B               154497
# greencard           11093
# E-3 Australian       1393
# H-1B1 Singapore       148
# H-1B1 Chile           147
# Name: VISA_CLASS, dtype: int64

# %%
# Top Employers By Count

salary_data['EMPLOYER_NAME'].value_counts()
# Out:
# GOOGLE INC.                                           6213
# FUJITSU AMERICA, INC.                                 1814
# INTEL CORPORATION                                     1781
# MICROSOFT CORPORATION                                 1364
# QUALCOMM TECHNOLOGIES, INC.                           1277
#                                                       ...
# SYSTEM LOGISTICS CORPORATION                             1
# OMAZE, INC.                                              1
# FRESENIUS HEALTH PARTNERS CARE SYSTEMS, INC., A FR       1
# BARNES GROUP INC.                                        1
# SACRED HEART SCHOOL                                      1
# Name: EMPLOYER_NAME, Length: 23773, dtype: int64

# %%
# Job Titles and Total number of Each Included in Data 

salary_data['JOB_TITLE_SUBGROUP'].value_counts()
# Out:
# software engineer        99364
# business analyst         27811
# assistant professor      18866
# teacher                  13912
# data analyst              3840
# attorney                  1488
# data scientist            1227
# management consultant      770
# Name: JOB_TITLE_SUBGROUP, dtype: int64
