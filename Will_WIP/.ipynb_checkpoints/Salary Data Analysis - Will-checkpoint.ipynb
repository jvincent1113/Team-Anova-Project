# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
salary_data = pd.read_csv('salary_data_states.csv')
salary_data
# Out:
#                CASE_NUMBER          CASE_STATUS CASE_RECEIVED_DATE  \
# 0       I-200-14073-248840               denied          3/14/2014
# 1            A-15061-55212               denied          3/19/2015
# 2       I-200-13256-001092               denied          9/13/2013
# 3       I-200-14087-353657               denied          3/28/2014
# 4       I-203-14259-128844               denied          9/16/2014
# ...                    ...                  ...                ...
# 167273  I-200-12241-209885  certified-withdrawn          8/28/2012
# 167274  I-200-11305-143547               denied          11/1/2011
# 167275  I-200-11313-833007            certified          11/9/2011
# 167276  I-200-11312-798611               denied          11/8/2011
# 167277  I-200-11297-523711               denied         10/24/2011
#
#        DECISION_DATE                                      EMPLOYER_NAME  \
# 0          3/21/2014                ADVANCED TECHNOLOGY GROUP USA, INC.
# ...

# %%
salary_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167278 entries, 0 to 167277
# Data columns (total 27 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   CASE_NUMBER                     167278 non-null  object
#  1   CASE_STATUS                     167278 non-null  object
#  2   CASE_RECEIVED_DATE              167278 non-null  object
#  3   DECISION_DATE                   167278 non-null  object
#  4   EMPLOYER_NAME                   167278 non-null  object
#  5   PREVAILING_WAGE_SUBMITTED       167278 non-null  float64
#  6   PREVAILING_WAGE_SUBMITTED_UNIT  167278 non-null  object
#  7   PAID_WAGE_SUBMITTED             167278 non-null  float64
#  8   PAID_WAGE_SUBMITTED_UNIT        167278 non-null  object
#  9   JOB_TITLE                       167278 non-null  object
#  10  WORK_CITY                       167275 non-null  object
#  11  EDUCATION_LEVEL_REQUIRED        11093 non-null   object
# ...

# %%
salary_data.describe()
# Out:
#        PREVAILING_WAGE_SUBMITTED  PAID_WAGE_SUBMITTED  \
# count               1.672780e+05         1.672780e+05
# mean                7.115752e+04         8.164186e+04
# std                 3.874624e+04         4.147703e+04
# min                 5.050000e+00         5.050000e+00
# 25%                 5.447500e+04         6.100000e+04
# 50%                 6.970100e+04         7.700000e+04
# 75%                 8.993700e+04         1.000000e+05
# max                 6.217100e+06         2.500000e+06
#
#        EXPERIENCE_REQUIRED_NUM_MONTHS  PREVAILING_WAGE_PER_YEAR  \
# count                     4965.000000             167210.000000
# mean                        34.692044              74274.868236
# std                         22.317783              25356.245893
# min                          0.000000              10504.000000
# 25%                         12.000000              56880.000000
# 50%                         24.000000              70928.000000
# ...

# %%
salary_data['PREVAILING_WAGE_PER_YEAR'].describe()
# Out:
# count    167210.000000
# mean      74274.868236
# std       25356.245893
# min       10504.000000
# 25%       56880.000000
# 50%       70928.000000
# 75%       90459.000000
# max      320000.000000
# Name: PREVAILING_WAGE_PER_YEAR, dtype: float64

# %%
salary_data['PAID_WAGE_PER_YEAR'].describe()
# Out:
# count    1.672780e+05
# mean     8.553277e+04
# std      3.873847e+04
# min      1.050000e+04
# 25%      6.300000e+04
# 50%      7.860000e+04
# 75%      1.000060e+05
# max      2.500000e+06
# Name: PAID_WAGE_PER_YEAR, dtype: float64

# %%
salary_data.isnull()
# Out:
#         CASE_NUMBER  CASE_STATUS  CASE_RECEIVED_DATE  DECISION_DATE  \
# 0             False        False               False          False
# 1             False        False               False          False
# 2             False        False               False          False
# 3             False        False               False          False
# 4             False        False               False          False
# ...             ...          ...                 ...            ...
# 167273        False        False               False          False
# 167274        False        False               False          False
# 167275        False        False               False          False
# 167276        False        False               False          False
# 167277        False        False               False          False
#
#         EMPLOYER_NAME  PREVAILING_WAGE_SUBMITTED  \
# 0               False                      False
# ...

# %%
salary_data['PREVAILING_WAGE_PER_YEAR'].min()
# Out:
# 10504.0

# %%
salary_data[salary_data['EMPLOYER_NAME'] == 'SAN FRANCISCO STATE UNIVERSITY']
# Out:
#                CASE_NUMBER CASE_STATUS CASE_RECEIVED_DATE DECISION_DATE  \
# 1            A-15061-55212      denied          3/19/2015     3/19/2015
# 138392  I-200-15070-455673      denied          3/11/2015     3/20/2015
# 138393  I-200-13126-710556   certified          5/13/2014     5/19/2014
# 138396  I-200-14059-827393   certified           3/3/2014      3/7/2014
# 138397  I-200-14091-552288      denied           4/2/2014      4/8/2014
# 138398  I-200-14100-082684   certified          4/10/2014     4/16/2014
# 138404  I-200-14129-614105   certified          5/19/2014     5/23/2014
# 138405  I-200-14133-571816   certified          5/13/2014     5/19/2014
# 140256  I-200-12306-433645   certified          11/1/2012     11/7/2012
# 140258  I-200-13037-772099   certified           2/6/2013     2/12/2013
# 140260  I-200-13092-597091   certified           4/2/2013      4/8/2013
# 140261  I-200-13101-002231   certified          4/11/2013     4/17/2013
# ...

# %%
salary_data['WORK_STATE'].value_counts() / salary_data['WORK_STATE'].count() * 100
# Out:
# California                  27.966618
# Texas                        9.264817
# New York                     6.798862
# New Jersey                   6.096438
# Illinois                     4.430349
# Massachusetts                4.093784
# Virginia                     3.605375
# Georgia                      3.356688
# Pennsylvania                 2.824639
# Washington                   2.755891
# Florida                      2.429489
# Michigan                     2.297971
# North Carolina               2.138954
# Maryland                     1.957819
# Ohio                         1.908201
# Missouri                     1.657719
# Arizona                      1.536365
# Minnesota                    1.264960
# Connecticut                  1.209364
# Indiana                      0.966654
# Colorado                     0.964861
# Oregon                       0.917634
# Wisconsin                    0.856658
# District of Columbia         0.818996
# Tennessee                    0.649816
# ...
